# %%
#%matplotlib notebook
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
from io import StringIO
import pandas as pd
import numpy as np


# lib437.combine_data('SSU-01_2016-04-27.csv', 'SSU-02_2016-04-27(outside).csv', 'TA-run-2.csv')
combined = pd.read_csv('TA-run-2.csv', parse_dates=True, index_col=0)

# %%
combined[['t_in', 't_out']].plot(title='Second TA Run, R-3?')
plt.ylabel('Temperature (C)')
plt.show()

# %%
(combined['t_in'] - combined['t_out']).plot()
plt.title('Temperature Difference above Ambient')
plt.ylabel('Temperature (C)')
plt.show()
